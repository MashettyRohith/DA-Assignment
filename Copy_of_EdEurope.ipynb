# %%
import pandas as pd
import requests
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup

# %%
presponse = requests.get('https://visaguide.world/europe/')

# %%
gdpresponse = requests.get('https://en.m.wikipedia.org/wiki/List_of_sovereign_states_in_Europe_by_GDP_(nominal)')

# %%
popsoup = BeautifulSoup(presponse.text, 'html.parser')

# %%
gdpsoup = BeautifulSoup(gdpresponse.text, 'html.parser')

# %%
poptable=popsoup.find_all('table')

# %%
gdptable=gdpsoup.find_all('table')

# %%
popheadings = poptable[1].find_all('th')
popheadings
# Out:
# [<th>Country</th>, <th>Capital</th>, <th>Area</th>, <th>Population (2021)</th>]

# %%
gdpheadings=gdptable[0].find_all('th')
gdpheadings
# Out:
# [<th>Country
#  </th>,
#  <th>2024<sup class="reference" id="cite_ref-4"><a href="#cite_note-4"><span class="cite-bracket">[</span>4<span class="cite-bracket">]</span></a></sup>
#  </th>,
#  <th>2023<sup class="reference" id="cite_ref-IMFWEO_5-0"><a href="#cite_note-IMFWEO-5"><span class="cite-bracket">[</span>5<span class="cite-bracket">]</span></a></sup>
#  </th>,
#  <th>2022
#  </th>,
#  <th>2021<sup class="reference" id="cite_ref-WPIMFWEO_6-0"><a href="#cite_note-WPIMFWEO-6"><span class="cite-bracket">[</span>6<span class="cite-bracket">]</span></a></sup></th>,
#  <th width="60">2020<sup class="reference" id="cite_ref-WPIMFWEO_6-1"><a href="#cite_note-WPIMFWEO-6"><span class="cite-bracket">[</span>6<span class="cite-bracket">]</span></a></sup></th>,
#  <th width="60">2019 </th>,
#  <th width="60">2018 </th>,
#  <th width="60">2017 </th>,
#  <th width="60">2016 </th>,
#  <th width="60">2015 </th>,
#  <th width="60">2014 </th>,
#  <th width="60">2013 </th>,
#  <th width="60">2012 </th>,
#  <th width="60">2011 </th>,
#  <th width="70">2010
#  </th>]

# %%
popheadings=[i.get_text(strip=True) for i in popheadings]
popheadings
# Out:
# ['Country', 'Capital', 'Area', 'Population (2021)']

# %%
gdpheadings1=[i.get_text(strip=True)for i in gdpheadings]
gdpheadings1
# Out:
# ['Country',
#  '2024[4]',
#  '2023[5]',
#  '2022',
#  '2021[6]',
#  '2020[6]',
#  '2019',
#  '2018',
#  '2017',
#  '2016',
#  '2015',
#  '2014',
#  '2013',
#  '2012',
#  '2011',
#  '2010']

# %%
gdpheadings=gdpheadings1
gdpheadings
# Out:
# ['Country',
#  '2024[4]',
#  '2023[5]',
#  '2022',
#  '2021[6]',
#  '2020[6]',
#  '2019',
#  '2018',
#  '2017',
#  '2016',
#  '2015',
#  '2014',
#  '2013',
#  '2012',
#  '2011',
#  '2010']

# %%
gdpheadings[1]=gdpheadings[1][:4]

# %%
gdpheadings
# Out:
# ['Country',
#  '2024',
#  '2023[5]',
#  '2022',
#  '2021[6]',
#  '2020[6]',
#  '2019',
#  '2018',
#  '2017',
#  '2016',
#  '2015',
#  '2014',
#  '2013',
#  '2012',
#  '2011',
#  '2010']

# %%
poprows=poptable[1].find_all('td')
poprows
# Out:
# [<td>Albania</td>,
#  <td>Tirana</td>,
#  <td>28,748 km²</td>,
#  <td>2.8 million</td>,
#  <td>Andorra</td>,
#  <td>Andorra la Vella</td>,
#  <td>468 km²</td>,
#  <td>77,335</td>,
#  <td>Austria</td>,
#  <td>Vienna</td>,
#  <td>83,858 km²</td>,
#  <td>9 million</td>,
#  <td>Belarus</td>,
#  <td>Minsk</td>,
#  <td>207,560 km²</td>,
#  <td>9.4 million</td>,
#  <td>Belgium</td>,
#  <td>Brussels</td>,
#  <td>30,528 km²</td>,
#  <td>11.6 million</td>,
#  <td>Bosnia and Herzegovina</td>,
#  <td>Sarajevo</td>,
#  <td>51,129 km²</td>,
#  <td>3.2 million</td>,
#  <td>Bulgaria</td>,
#  <td>Sofia</td>,
#  <td>110,910 km²</td>,
#  <td>6.8 million</td>,
#  <td>Croatia</td>,
#  <td>Zagreb</td>,
#  <td>56,542 km²</td>,
#  <td>4 million</td>,
#  <td>Cyprus</td>,
#  <td>Nicosia</td>,
#  <td>9,251 km²</td>,
#  <td>1.2 million</td>,
#  <td>Czech Republic</td>,
#  <td>Prague</td>,
#  <td>78,866 km²</td>,
#  <td>10.7 million</td>,
#  <td>Denmark</td>,
#  <td>Copenhagen</td>,
#  <td>43,094 km²</td>,
#  <td>5.8 million</td>,
#  <td>Estonia</td>,
#  <td>Tallinn</td>,
#  <td>45,226 km²</td>,
#  <td>1.3 million</td>,
#  <td>Finland</td>,
#  <td>Helsinki</td>,
#  <td>338,455 km²</td>,
#  <td>5.5 million</td>,
#  <td>France</td>,
#  <td>Paris</td>,
#  <td>547,030 km²</td>,
#  <td>65.4 million</td>,
#  <td>Germany</td>,
#  <td>Berlin</td>,
#  <td>357,168 km²</td>,
#  <td>83.9 million</td>,
#  <td>Greece</td>,
#  <td>Athens</td>,
#  <td>131,957 km²</td>,
#  <td>10.3 million</td>,
#  <td>Hungary</td>,
#  <td>Budapest</td>,
#  <td>93,030 km²</td>,
#  <td>9.6 million</td>,
#  <td>Iceland</td>,
#  <td>Reykjavik</td>,
#  <td>103,000 km²</td>,
#  <td>343,353</td>,
#  <td>Ireland</td>,
#  <td>Dublin</td>,
#  <td>70,280 km²</td>,
#  <td>4.9 million</td>,
#  <td>Italy</td>,
#  <td>Rome</td>,
#  <td>301,338 km²</td>,
#  <td>60.3 million</td>,
#  <td>Kosovo</td>,
#  <td>Prishtina</td>,
#  <td>10,887 km²</td>,
#  <td>1.9 million</td>,
#  <td>Latvia</td>,
#  <td>Riga</td>,
#  <td>64,589 km²</td>,
#  <td>1.8 million</td>,
#  <td>Liechtenstein</td>,
#  <td>Vaduz</td>,
#  <td>160 km²</td>,
#  <td>38.25</td>,
#  <td>Lithuania</td>,
#  <td>Vilnius</td>,
#  <td>65,300 km²</td>,
#  <td>2.6 million</td>,
#  <td>Luxembourg</td>,
#  <td>Luxembourg</td>,
#  <td>2,586 km²</td>,
#  <td>634.814</td>,
#  <td>Malta</td>,
#  <td>Valletta</td>,
#  <td>316 km²</td>,
#  <td>442.784</td>,
#  <td>Moldova</td>,
#  <td>Chisinau</td>,
#  <td>33,846 km²</td>,
#  <td>4 million</td>,
#  <td>Monaco</td>,
#  <td>Monaco</td>,
#  <td>2.020 km²</td>,
#  <td>39.511</td>,
#  <td>Montenegro</td>,
#  <td>Podgorica</td>,
#  <td>13,812 km²</td>,
#  <td>628.053</td>,
#  <td>Netherlands</td>,
#  <td>Amsterdam</td>,
#  <td>41,543 km²</td>,
#  <td>17.1 million</td>,
#  <td>North Macedonia</td>,
#  <td>Skopje</td>,
#  <td>25,713 km²</td>,
#  <td>2 million</td>,
#  <td>Norway</td>,
#  <td>Oslo</td>,
#  <td>385,203 km²</td>,
#  <td>5.4 million</td>,
#  <td>Poland</td>,
#  <td>Warsaw</td>,
#  <td>312,685 km²</td>,
#  <td>37.7 million</td>,
#  <td>Portugal</td>,
#  <td>Lisbon</td>,
#  <td>92,212 km²</td>,
#  <td>10.1 million</td>,
#  <td>Romania</td>,
#  <td>Bucharest</td>,
#  <td>238,397 km²</td>,
#  <td>19.1 million</td>,
#  <td>Russia</td>,
#  <td>Moscow</td>,
#  <td>3,969,100 km²</td>,
#  <td>145.9 million</td>,
#  <td>San Marino</td>,
#  <td>San Marino</td>,
#  <td>61.2 km²</td>,
#  <td>34.017</td>,
#  <td>Serbia</td>,
#  <td>Belgrade</td>,
#  <td>88,361 km²</td>,
#  <td>8.6 million</td>,
#  <td>Slovakia</td>,
#  <td>Bratislava</td>,
#  <td>49,035 km²</td>,
#  <td>5.4 million</td>,
#  <td>Slovenia</td>,
#  <td>Ljubljana</td>,
#  <td>20,273 km²</td>,
#  <td>2 million</td>,
#  <td>Spain</td>,
#  <td>Madrid</td>,
#  <td>505,990 km²</td>,
#  <td>46.7 million</td>,
#  <td>Sweden</td>,
#  <td>Stockholm</td>,
#  <td>450,295 km²</td>,
#  <td>10.1 million</td>,
#  <td>Switzerland</td>,
#  <td>Bern</td>,
#  <td>41,285 km²</td>,
#  <td>8.7 million</td>,
#  <td>Ukraine</td>,
#  <td>Kyiv</td>,
#  <td>603,628 km²</td>,
#  <td>43.4 million</td>,
#  <td>United Kingdom</td>,
#  <td>London</td>,
#  <td>244,820 km²</td>,
#  <td>68.2 million</td>,
#  <td>Vatican City</td>,
#  <td>Vatican City</td>,
#  <td>0.44 km²</td>,
#  <td>800</td>]

# %%
poprows=[i.get_text(strip=True)for i in poprows]
poprows[:10]
# Out:
# ['Albania',
#  'Tirana',
#  '28,748 km²',
#  '2.8 million',
#  'Andorra',
#  'Andorra la Vella',
#  '468 km²',
#  '77,335',
#  'Austria',
#  'Vienna']

# %%
gdprows=gdptable[0].find_all('td')
gdprows
# Out:
# [<td><span class="flagicon"><span class="mw-image-border" typeof="mw:File"><span><noscript><img alt="" class="mw-file-element" data-file-height="600" data-file-width="1000" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/en/thumb/b/ba/Flag_of_Germany.svg/23px-Flag_of_Germany.svg.png" width="23"/></noscript><span class="lazy-image-placeholder" data-alt="" data-class="mw-file-element" data-height="14" data-mw-src="//upload.wikimedia.org/wikipedia/en/thumb/b/ba/Flag_of_Germany.svg/23px-Flag_of_Germany.svg.png" data-mw-srcset="//upload.wikimedia.org/wikipedia/en/thumb/b/ba/Flag_of_Germany.svg/35px-Flag_of_Germany.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/b/ba/Flag_of_Germany.svg/46px-Flag_of_Germany.svg.png 2x" data-width="23" style="width: 23px;height: 14px;"> </span></span></span> </span><a href="/wiki/Germany" title="Germany">Germany</a>
#  </td>,
#  <td>4,683.233
#  </td>,
#  <td>4,429.840
#  </td>,
#  <td>4,256.540</td>,
#  <td>4,230.172</td>,
#  <td>3,780.553</td>,
#  <td>3,863.344</td>,
#  <td>3,951.340</td>,
#  <td>3,664.511</td>,
#  <td>3,496.606</td>,
#  <td>3,383.091</td>,
#  <td>3,904.921</td>,
#  <td>3,753.687</td>,
#  <td>3,545.946</td>,
#  <td>3,761.142</td>,
#  <td>3,423.47
#  </td>,
#  <td><span class="flagicon"><span class="mw-image-border" typeof="mw:File"><span><noscript><img alt="" class="mw-file-element" data-file-height="600" data-file-width="1200" decoding="async" height="12" src="//upload.wikimedia.org/wikipedia/en/thumb/a/ae/Flag_of_the_United_Kingdom.svg/23px-Flag_of_the_United_Kingdom.svg.png" width="23"/></noscript><span class="lazy-image-placeholder" data-alt="" data-class="mw-file-element" data-height="12" data-mw-src="//upload.wikimedia.org/wikipedia/en/thumb/a/ae/Flag_of_the_United_Kingdom.svg/23px-Flag_of_the_United_Kingdom.svg.png" data-mw-srcset="//upload.wikimedia.org/wikipedia/en/thumb/a/ae/Flag_of_the_United_Kingdom.svg/35px-Flag_of_the_United_Kingdom.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/a/ae/Flag_of_the_United_Kingdom.svg/46px-Flag_of_the_United_Kingdom.svg.png 2x" data-width="23" style="width: 23px;height: 12px;"> </span></span></span> </span><a href="/wiki/United_Kingdom" title="United Kingdom">United Kingdom</a>
#  </td>,
#  <td>3,557.465
#  </td>,
#  <td>3,332.060
#  </td>,
#  <td>3,376.003</td>,
#  <td>3,108.416</td>,
#  <td>2,638.296</td>,
#  <td>2,743.586</td>,
#  <td>2,828.833</td>,
#  <td>2,640.067</td>,
#  <td>2,669.107</td>,
#  <td>2,897.060</td>,
#  <td>3,036.310</td>,
#  <td>2,755.356</td>,
#  <td>2,677.082</td>,
#  <td>2,635.799</td>,
#  <td>2,455.309
#  </td>,
#  <td><span class="flagicon"><span class="mw-image-border" typeof="mw:File"><span><noscript><img alt="" class="mw-file-element" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/en/thumb/c/c3/Flag_of_France.svg
#  </td>,
#  <td><span class="flagicon"><span class="mw-image-border" typeof="mw:File"><span><noscript><img alt="" class="mw-file-element" data-file-height="600" data-file-width="1000" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/47/Flag_of_Liechtenstein.svg/40px-Flag_of_Liechtenstein.svg.png" width="23"/></noscript><span class="lazy-image-placeholder" data-alt="" data-class="mw-file-element" data-height="14" data-mw-src="//upload.wikimedia.org/wikipedia/commons/thumb/4/47/Flag_of_Liechtenstein.svg/40px-Flag_of_Liechtenstein.svg.png" data-mw-srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/47/Flag_of_Liechtenstein.svg/60px-Flag_of_Liechtenstein.svg.png 2x" data-width="23" style="width: 23px;height: 14px;"> </span></span></span> </span><a href="/wiki/Liechtenstein" title="Liechtenstein">Liechtenstein</a><sup class="reference" id="cite_ref-9"><a href="#cite_note-9"><span class="cite-bracket">[</span>9<span class="cite-bracket">]</span></a></sup>
#  </td>,
#  <td>7.365
#  </td>,
#  <td>
#  </td>,
#  <td>N/A
#  </td>,
#  <td>-</td>,
#  <td>6.872</td>,
#  <td>-</td>,
#  <td>6.839</td>,
#  <td>-</td>,
#  <td>6.215</td>,
#  <td>6.268</td>,
#  <td>6.657</td>,
#  <td>6.392</td>,
#  <td>5.456</td>,
#  <td>5.740</td>,
#  <td>5.082
#  </td>,
#  <td><span class="flagicon"><span class="mw-image-border" typeof="mw:File"><span><noscript><img alt="" class="mw-file-element" data-file-height="700" data-file-width="1000" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/19/Flag_of_Andorra.svg/22px-Flag_of_Andorra.svg.png" width="22"/></noscript><span class="lazy-image-placeholder" data-alt="" data-class="mw-file-element" data-height="15" data-mw-src="//upload.wikimedia.org/wikipedia/commons/thumb/1/19/Flag_of_Andorra.svg/22px-Flag_of_Andorra.svg.png" data-mw-srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/19/Flag_of_Andorra.svg/33px-Flag_of_Andorra.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/1/19/Flag_of_Andorra.svg/43px-Flag_of_Andorra.svg.png 2x" data-width="22" style="width: 22px;height: 15px;"> </span></span></span> </span><a href="/wiki/Andorra" title="Andorra">Andorra</a><sup class="reference" id="cite_ref-10"><a href="#cite_note-10"><span class="cite-bracket">[</span>10<span class="cite-bracket">]</span></a></sup><sup class="reference" id="cite_ref-Parity_8-1"><a href="#cite_note-Parity-8"><span class="cite-bracket">[</span>8<span class="cite-bracket">]</span></a></sup>
#  </td>,
#  <td>3.900
#  </td>,
#  <td>3.669
#  </td>,
#  <td>3.400</td>,
#  <td>3.213</td>,
#  <td>2.864</td>,
#  <td>3.155</td>,
#  <td>3.238</td>,
#  <td>3.021</td>,
#  <td>2.879</td>,
#  <td>2.813</td>,
#  <td>3.355</td>,
#  <td>3.283</td>,
#  <td>3.164</td>,
#  <td>3.447</td>,
#  <td>3.359
#  </td>,
#  <td><span class="flagicon"><span class="mw-image-border" typeof="mw:File"><span><noscript><img alt="" class="mw-file-element" data-file-height="600" data-file-width="800" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/b1/Flag_of_San_Marino.svg/20px-Flag_of_San_Marino.svg.png" width="20"/></noscript><span class="lazy-image-placeholder" data-alt="" data-class="mw-file-element" data-height="15" data-mw-src="//upload.wikimedia.org/wikipedia/commons/thumb/b/b1/Flag_of_San_Marino.svg/20px-Flag_of_San_Marino.svg.png" data-mw-srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/b1/Flag_of_San_Marino.svg/31px-Flag_of_San_Marino.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/b1/Flag_of_San_Marino.svg/40px-Flag_of_San_Marino.svg.png 2x" data-width="20" style="width: 20px;height: 15px;"> </span></span></span> </span><a href="/wiki/San_Marino" title="San Marino">San Marino</a>
#  </td>,
#  <td>2.040
#  </td>,
#  <td>1.807
#  </td>,
#  <td>1.698</td>,
#  <td>1.728</td>,
#  <td>1.410</td>,
#  <td>1.591</td>,
#  <td>1.638</td>,
#  <td>1.528</td>,
#  <td>1.468</td>,
#  <td>1.420</td>,
#  <td>1.674</td>,
#  <td>1.678</td>,
#  <td>1.606</td>,
#  <td>1.813</td>,
#  <td>1.883
#  </td>]

# %%
gdprows=[i.get_text(strip=True) for i in gdprows]
gdprows[0:50:16]
# Out:
# ['Germany', 'United Kingdom', 'France', 'Italy']

# %%
popdict={}
n=0
for i in popheadings:
   popdict[i]=[poprows[j]for j in range(n,len(poprows),len(popheadings))]
   n+=1
popdict
# Out:
# {'Country': ['Albania',
#   'Andorra',
#   'Austria',
#   'Belarus',
#   'Belgium',
#   'Bosnia and Herzegovina',
#   'Bulgaria',
#   'Croatia',
#   'Cyprus',
#   'Czech Republic',
#   'Denmark',
#   'Estonia',
#   'Finland',
#   'France',
#   'Germany',
#   'Greece',
#   'Hungary',
#   'Iceland',
#   'Ireland',
#   'Italy',
#   'Kosovo',
#   'Latvia',
#   'Liechtenstein',
#   'Lithuania',
#   'Luxembourg',
#   'Malta',
#   'Moldova',
#   'Monaco',
#   'Montenegro',
#   'Netherlands',
#   'North Macedonia',
#   'Norway',
#   'Poland',
#   'Portugal',
#   'Romania',
#   'Russia',
#   'San Marino',
#   'Serbia',
#   'Slovakia',
#   'Slovenia',
#   'Spain',
#   'Sweden',
#   'Switzerland',
#   'Ukraine',
#   'United Kingdom',
#   'Vatican City'],
#  'Capital': ['Tirana',
#   'Andorra la Vella',
#   'Vienna',
#   'Minsk',
#   'Brussels',
#   'Sarajevo',
#   'Sofia',
#   'Zagreb',
#   'Nicosia',
#   'Prague',
#   'Copenhagen',
#   'Tallinn',
#   'Helsinki',
#   'Paris',
#   'Berlin',
#   'Athens',
#   'Budapest',
#   'Reykjavik',
#   'Dublin',
#   'Rome',
#   'Prishtina',
#   'Riga',
#   'Vaduz',
#   'Vilnius',
#   'Luxembourg',
#   'Valletta',
#   'Chisinau',
#   'Monaco',
#   'Podgorica',
#   'Amsterdam',
#   'Skopje',
#   'Oslo',
#   'Warsaw',
#   'Lisbon',
#   'Bucharest',
#   'Moscow',
#   'San Marino',
#   'Belgrade',
#   'Bratislava',
#   'Ljubljana',
#   'Madrid',
#   'Stockholm',
#   'Bern',
#   'Kyiv',
#   'London',
#   'Vatican City'],
#  'Area': ['28,748 km²',
#   '468 km²',
#   '83,858 km²',
#   '207,560 km²',
#   '30,528 km²',
#   '51,129 km²',
#   '110,910 km²',
#   '56,542 km²',
#   '9,251 km²',
#   '78,866 km²',
#   '43,094 km²',
#   '45,226 km²',
#   '338,455 km²',
#   '547,030 km²',
#   '357,168 km²',
#   '131,957 km²',
#   '93,030 km²',
#   '103,000 km²',
#   '70,280 km²',
#   '301,338 km²',
#   '10,887 km²',
#   '64,589 km²',
#   '160 km²',
#   '65,300 km²',
#   '2,586 km²',
#   '316 km²',
#   '33,846 km²',
#   '2.020 km²',
#   '13,812 km²',
#   '41,543 km²',
#   '25,713 km²',
#   '385,203 km²',
#   '312,685 km²',
#   '92,212 km²',
#   '238,397 km²',
#   '3,969,100 km²',
#   '61.2 km²',
#   '88,361 km²',
#   '49,035 km²',
#   '20,273 km²',
#   '505,990 km²',
#   '450,295 km²',
#   '41,285 km²',
#   '603,628 km²',
#   '244,820 km²',
#   '0.44 km²'],
#  'Population (2021)': ['2.8 million',
#   '77,335',
#   '9 million',
#   '9.4 million',
#   '11.6 million',
#   '3.2 million',
#   '6.8 million',
#   '4 million',
#   '1.2 million',
#   '10.7 million',
#   '5.8 million',
#   '1.3 million',
#   '5.5 million',
#   '65.4 million',
#   '83.9 million',
#   '10.3 million',
#   '9.6 million',
#   '343,353',
#   '4.9 million',
#   '60.3 million',
#   '1.9 million',
#   '1.8 million',
#   '38.25',
#   '2.6 million',
#   '634.814',
#   '442.784',
#   '4 million',
#   '39.511',
#   '628.053',
#   '17.1 million',
#   '2 million',
#   '5.4 million',
#   '37.7 million',
#   '10.1 million',
#   '19.1 million',
#   '145.9 million',
#   '34.017',
#   '8.6 million',
#   '5.4 million',
#   '2 million',
#   '46.7 million',
#   '10.1 million',
#   '8.7 million',
#   '43.4 million',
#   '68.2 million',
#   '800']}

# %%
gdpdict={}
n=0
for i in gdpheadings:
    gdpdict[i]=[gdprows[j]for j in range(n,len(gdprows),len(gdpheadings1))]
    n+=1
gdpdict
# Out:
# {'Country': ['Germany',
#   'United Kingdom',
#   'France',
#   'Italy',
#   'Russia',
#   'Spain',
#   'Turkey',
#   'Netherlands',
#   'Switzerland',
#   'Poland',
#   'Belgium',
#   'Sweden',
#   'Ireland',
#   'Austria',
#   'Norway',
#   'Denmark',
#   'Romania',
#   'Czech Republic',
#   'Finland',
#   'Portugal',
#   'Kazakhstan',
#   'Greece',
#   'Hungary',
#   'Ukraine',
#   'Slovakia',
#   'Bulgaria',
#   'Luxembourg',
#   'Croatia',
#   'Lithuania',
#   'Serbia',
#   'Azerbaijan',
#   'Belarus',
#   'Slovenia',
#   'Latvia',
#   'Estonia',
#   'Cyprus',
#   'Iceland',
#   'Georgia',
#   'Bosnia and Herzegovina',
#   'Albania',
#   'Armenia',
#   'Malta',
#   'Moldova',
#   'North Macedonia',
#   'Kosovo',
#   'Monaco[7][8]',
#   'Montenegro',
#   'Liechtenstein[9]',
#   'Andorra[10][8]',
#   'San Marino'],
#  '2024': ['4,683.233',
#   '3,557.465',
#   '3,156.325',
#   '2,365.541',
#   '2,158.786',
#   '1,724.379',
#   '1,312.932',
#   '1,209.072',
#   '935.316',
#   '908.561',
#   '657.821',
#   '605.506',
#   '559.246',
#   '533.147',
#   '501.051',
#   '401.531',
#   '376.243',
#   '343.023',
#   '308.055',
#   '300.711',
#   '288.280',
#   '250.615',
#   '226.413',
#   '183.255',
#   '141.144',
#   '107.427',
#   '90.414',
#   '88.646',
#   '82.064',
#   '81.471',
#   '75.749',
#   '72.993',
#   '72.607',
#   '45.245',
#   '42.778',
#   '34.221',
#   '33.338',
#   '32.802',
#   '28.206',
#   '26.130',
#   '25.408',
#   '24.095',
#   '18.356',
#   '15.873',
#   '11.318',
#   '8.784',
#   '8.006',
#   '7.365',
#   '3.900',
#   '2.040'],
#  '2023[5]': ['4,429.840',
#   '3,332.060',
#   '3,049.020',
#   '2,186.080',
#   '1,862.470',
#   '1,620.091',
#   '1,154.060',
#   '1,092.750',
#   '905.684',
#   '842.172',
#   '624.248',
#   '599.052',
#   '594.095',
#   '515.199',
#   '554.105',
#   '405.626',
#   '348.902',
#   '330.483',
#   '301.670',
#   '267.721',
#   '245.695',
#   '239.300',
#   '188.505',
#   '148.712',
#   '127.533',
#   '100.635',
#   '86.971',
#   '78.881',
#   '78.346',
#   '73.961',
#   '70.030',
#   '73.543',
#   '68.108',
#   '47.398',
#   '41.551',
#   '30.864',
#   '28.625',
#   '27.947',
#   '28.488',
#   '20.177',
#   '23.725',
#   '19.405',
#   '15.829',
#   '15.278',
#   '9.990',
#   '',
#   '7.416',
#   '',
#   '3.669',
#   '1.807'],
#  '2022': ['4,256.540',
#   '3,376.003',
#   '2,936.702',
#   '2,058.330',
#   '2,133.092',
#   '1,446.498',
#   '905.527',
#   '1,013.595',
#   '841.969',
#   '699.559',
#   '609.887',
#   '621.241',
#   '516.146',
#   '479.815',
#   '541.938',
#   '399.100',
#   '312.492',
#   '296.238',
#   '297.617',
#   '251.915',
#   '225.784',
#   '222.770',
#   '197.813',
#   '198.316',
#   '118.434',
#   '89.533',
#   '86.898',
#   '69.459',
#   '69.782',
#   '65.037',
#   '73.369',
#   '59.394',
#   '63.647',
#   '40.266',
#   '37.202',
#   '27.726',
#   '27.865',
#   '20.889',
#   '23.358',
#   '17.942',
#   '21.347',
#   '17.251',
#   '13.811',
#   '14.198',
#   '9.660',
#   'N/A',
#   '6.018',
#   'N/A',
#   '3.400',
#   '1.698'],
#  '2021[6]': ['4,230.172',
#   '3,108.416',
#   '2,940.428',
#   '2,120.232',
#   '1,778.530',
#   '1,461.245',
#   '817.508',
#   '1,007.562',
#   '810.830',
#   '655.332',
#   '581.848',
#   '622.365',
#   '516.253',
#   '481.209',
#   '445.507',
#   '396.666',
#   '287.279',
#   '276.914',
#   '296.016',
#   '251.709',
#   '197.112',
#   '211.645',
#   '180.959',
#   '181.038',
#   '116.748',
#   '77.907',
#   '83.771',
#   '63.399',
#   '62.635',
#   '60.669',
#   '52.645',
#   '65.754',
#   '60.890',
#   '37.199',
#   '36.039',
#   '26.546',
#   '25.476',
#   '17.846',
#   '21.692',
#   '16.770',
#   '13.612',
#   '16.695',
#   '12.396',
#   '13.885',
#   '8.958',
#   '-',
#   '5.494',
#   '-',
#   '3.213',
#   '1.728'],
#  '2020[6]': ['3,780.553',
#   '2,638.296',
#   '2,551.451',
#   '1,848.222',
#   '1,464.078',
#   '1,289.784',
#   '720.110',
#   '886.339',
#   '707.868',
#   '580.894',
#   '503.416',
#   '529.054',
#   '399.064',
#   '432.894',
#   '366.386',
#   '339.626',
#   '248.624',
#   '241.975',
#   '267.856',
#   '221.716',
#   '171.082',
#   '194.376',
#   '149.939',
#   '142.250',
#   '101.892',
#   '67.917',
#   '68.613',
#   '56.768',
#   '55.064',
#   '51.999',
#   '41.666',
#   '57.708',
#   '51.802',
#   '33.015',
#   '30.468',
#   '23.246',
#   '20.805',
#   '16.316',
#   '18.893',
#   '14.034',
#   '12.813',
#   '14.290',
#   '11.241',
#   '12.510',
#   '7.484',
#   '6.817',
#   '4.943',
#   '6.872',
#   '2.864',
#   '1.410'],
#  '2019': ['3,863.344',
#   '2,743.586',
#   '2,707.074',
#   '2,001.440',
#   '1,637.892',
#   '1,403.496',
#   '759.450',
#   '902.355',
#   '715.360',
#   '565.854',
#   '517.609',
#   '528.929',
#   '384.940',
#   '447.718',
#   '417.627',
#   '347.176',
#   '243.698',
#   '246.953',
#   '269.654',
#   '236.408',
#   '181.667',
#   '214.012',
#   '170.407',
#   '150.401',
#   '106.552',
#   '66.250',
#   '69.453',
#   '60.702',
#   '53.641',
#   '51.523',
#   '47.171',
#   '62.572',
#   '54.154',
#   '35.045',
#   '31.038',
#   '24.280',
#   '23.918',
#   '15.925',
#   '20.106',
#   '15.418',
#   '13.444',
#   '14.859',
#   '11.688',
#   '12.672',
#   '7.996',
#   '7.424',
#   '5.424',
#   '-',
#   '3.155',
#   '1.591'],
#  '2018': ['3,951.340',
#   '2,828.833',
#   '2,780.152',
#   '2,075.856',
#   '1,657.290',
#   '1,431.643',
#   '779.694',
#   '914.519',
#   '705.546',
#   '585.816',
#   '532.268',
#   '556.073',
#   '382.754',
#   '456.166',
#   '434.167',
#   '352.058',
#   '239.552',
#   '245.226',
#   '274.210',
#   '240.901',
#   '179.340',
#   '218.230',
#   '161.182',
#   '130.857',
#   '106.573',
#   '65.197',
#   '69.553',
#   '60.805',
#   '53.302',
#   '50.509',
#   '46.940',
#   '59.643',
#   '54.059',
#   '34.882',
#   '30.761',
#   '24.493',
#   '25.965',
#   '16.209',
#   '20.162',
#   '15.059',
#   '12.433',
#   '14.560',
#   '11.309',
#   '12.670',
#   '7.947',
#   '7.188',
#   '5.457',
#   '6.839',
#   '3.238',
#   '1.638'],
#  '2017': ['3,664.511',
#   '2,640.067',
#   '2,591.775',
#   '1,950.703',
#   '1,579.293',
#   '1,321.754',
#   '858.932',
#   '833.575',
#   '680.029',
#   '526.749',
#   '495.953',
#   '540.545',
#   '335.211',
#   '417.721',
#   '398.394',
#   '329.866',
#   '211.407',
#   '215.914',
#   '252.867',
#   '221.280',
#   '166.806',
#   '203.493',
#   '139.844',
#   '112.125',
#   '95.821',
#   '58.342',
#   '62.449',
#   '55.201',
#   '47.645',
#   '44.120',
#   '41.375',
#   '54.723',
#   '48.545',
#   '30.528',
#   '26.850',
#   '22.189',
#   '24.457',
#   '15.080',
#   '18.081',
#   '13.059',
#   '11.527',
#   '12.764',
#   '9.670',
#   '11.308',
#   '7.243',
#   '6.291',
#   '4.855',
#   '-',
#   '3.021',
#   '1.528'],
#  '2016': ['3,496.606',
#   '2,669.107',
#   '2,466.152',
#   '1,869.973',
#   '1,282.663',
#   '1,243.016',
#   '869.280',
#   '783.852',
#   '670.247',
#   '471.843',
#   '469.931',
#   '512.205',
#   '301.968',
#   '394.215',
#   '371.345',
#   '311.988',
#   '188.495',
#   '195.090',
#   '239.150',
#   '206.361',
#   '137.289',
#   '195.303',
#   '126.008',
#   '93.313',
#   '89.885',
#   '53.236',
#   '58.985',
#   '51.623',
#   '42.991',
#   '40.630',
#   '37.830',
#   '47.703',
#   '44.660',
#   '27.707',
#   '23.994',
#   '20.461',
#   '20.618',
#   '14.378',
#   '16.910',
#   '11.868',
#   '10.546',
#   '11.446',
#   '8.072',
#   '10.686',
#   '6.717',
#   '6.390',
#   '4.376',
#   '6.215',
#   '2.879',
#   '1.468'],
#  '2015': ['3,383.091',
#   '2,897.060',
#   '2,439.435',
#   '1,833.195',
#   '1,363.707',
#   '1,206.165',
#   '864.071',
#   '765.650',
#   '679.721',
#   '477.568',
#   '456.067',
#   '498.118',
#   '290.858',
#   '381.998',
#   '386.663',
#   '302.673',
#   '177.895',
#   '186.830',
#   '232.582',
#   '199.521',
#   '184.388',
#   '196.690',
#   '123.074',
#   '90.489',
#   '87.814',
#   '50.201',
#   '57.233',
#   '49.519',
#   '41.538',
#   '39.629',
#   '50.844',
#   '56.329',
#   '43.124',
#   '26.986',
#   '22.916',
#   '19.691',
#   '17.389',
#   '13.993',
#   '16.210',
#   '11.364',
#   '10.553',
#   '10.701',
#   '7.726',
#   '10.067',
#   '6.444',
#   '6.194',
#   '4.055',
#   '6.268',
#   '2.813',
#   '1.420'],
#  '2014': ['3,904.921',
#   '3,036.310',
#   '2,856.697',
#   '2,155.151',
#   '2,056.583',
#   '1,380.245',
#   '938.512',
#   '892.397',
#   '709.496',
#   '545.284',
#   '531.651',
#   '574.413',
#   '259.200',
#   '442.698',
#   '499.338',
#   '352.994',
#   '199.628',
#   '207.818',
#   '273.042',
#   '229.995',
#   '221.416',
#   '237.406',
#   '140.083',
#   '130.571',
#   '101.109',
#   '56.815',
#   '66.209',
#   '57.683',
#   '48.632',
#   '47.062',
#   '75.240',
#   '78.736',
#   '49.969',
#   '31.385',
#   '26.658',
#   '23.401',
#   '17.758',
#   '16.510',
#   '18.522',
#   '13.219',
#   '11.610',
#   '11.302',
#   '9.510',
#   '11.378',
#   '7.398',
#   '7.069',
#   '4.595',
#   '6.657',
#   '3.355',
#   '1.674'],
#  '2013': ['3,753.687',
#   '2,755.356',
#   '2,811.957',
#   '2,131.159',
#   '2,289.244',
#   '1,362.187',
#   '957.504',
#   '877.198',
#   '688.747',
#   '524.399',
#   '521.090',
#   '579.361',
#   '238.708',
#   '430.203',
#   '523.502',
#   '343.584',
#   '190.948',
#   '209.402',
#   '270.065',
#   '226.144',
#   '236.635',
#   '239.937',
#   '135.221',
#   '179.572',
#   '98.509',
#   '55.557',
#   '61.759',
#   '58.158',
#   '46.423',
#   '48.394',
#   '74.160',
#   '75.496',
#   '48.131',
#   '30.260',
#   '25.145',
#   '24.094',
#   '16.034',
#   '16.140',
#   '18.155',
#   '12.804',
#   '11.121',
#   '10.154',
#   '9.496',
#   '10.824',
#   '7.075',
#   '6.595',
#   '4.466',
#   '6.392',
#   '3.283',
#   '1.678'],
#  '2012': ['3,545.946',
#   '2,677.082',
#   '2,685.311',
#   '2,073.971',
#   '2,202.672',
#   '1,330.995',
#   '880.141',
#   '839.436',
#   '667.890',
#   '500.846',
#   '498.161',
#   '544.482',
#   '225.140',
#   '409.652',
#   '510.229',
#   '327.149',
#   '171.196',
#   '207.376',
#   '256.849',
#   '216.488',
#   '207.999',
#   '245.807',
#   '127.857',
#   '175.707',
#   '93.466',
#   '53.901',
#   '56.709',
#   '56.549',
#   '42.887',
#   '43.300',
#   '69.687',
#   '65.669',
#   '46.378',
#   '28.141',
#   '23.057',
#   '25.055',
#   '14.724',
#   '15.847',
#   '17.207',
#   '12.323',
#   '10.619',
#   '9.215',
#   '8.708',
#   '9.751',
#   '6.503',
#   '5.818',
#   '4.090',
#   '5.456',
#   '3.164',
#   '1.606'],
#  '2011': ['3,761.142',
#   '2,635.799',
#   '2,864.030',
#   '2,278.376',
#   '2,044.618',
#   '1,487.569',
#   '838.508',
#   '904.915',
#   '699.670',
#   '528.571',
#   '527.492',
#   '563.797',
#   '238.088',
#   '431.515',
#   '498.832',
#   '344.003',
#   '183.443',
#   '227.948',
#   '273.925',
#   '245.119',
#   '192.626',
#   '288.062',
#   '140.782',
#   '163.161',
#   '98.271',
#   '57.420',
#   '60.060',
#   '62.399',
#   '43.564',
#   '49.280',
#   '65.990',
#   '61.368',
#   '51.338',
#   '28.496',
#   '23.191',
#   '27.454',
#   '15.159',
#   '14.435',
#   '18.629',
#   '12.896',
#   '10.142',
#   '9.511',
#   '8.417',
#   '10.659',
#   '6.699',
#   '6.245',
#   '4.543',
#   '5.740',
#   '3.447',
#   '1.813'],
#  '2010': ['3,423.47',
#   '2,455.309',
#   '2,647.537',
#   '2,129.021',
#   '1,632.841',
#   '1,427.989',
#   '776.558',
#   '848.133',
#   '583.053',
#   '479.161',
#   '484.450',
#   '488.909',
#   '222.533',
#   '392.623',
#   '429.131',
#   '321.995',
#   '166.225',
#   '207.478',
#   '248.262',
#   '238.748',
#   '148.047',
#   '299.919',
#   '130.923',
#   '136.011',
#   '89.668',
#   '50.611',
#   '53.312',
#   '59.866',
#   '37.200',
#   '41.369',
#   '52.913',
#   '57.220',
#   '48.103',
#   '23.809',
#   '19.536',
#   '25.608',
#   '13.684',
#   '11.638',
#   '17.164',
#   '11.938',
#   '9.260',
#   '8.757',
#   '6.977',
#   '9.415',
#   '5.841',
#   '5.556',
#   '4.147',
#   '5.082',
#   '3.359',
#   '1.883']}

# %%
popdf = pd.DataFrame(popdict)
gdpdf = pd.DataFrame(gdpdict)

# %%
popdf
# Out:
#                    Country           Capital           Area Population (2021)
# 0                  Albania            Tirana     28,748 km²       2.8 million
# 1                  Andorra  Andorra la Vella        468 km²            77,335
# 2                  Austria            Vienna     83,858 km²         9 million
# 3                  Belarus             Minsk    207,560 km²       9.4 million
# 4                  Belgium          Brussels     30,528 km²      11.6 million
# 5   Bosnia and Herzegovina          Sarajevo     51,129 km²       3.2 million
# 6                 Bulgaria             Sofia    110,910 km²       6.8 million
# 7                  Croatia            Zagreb     56,542 km²         4 million
# 8                   Cyprus           Nicosia      9,251 km²       1.2 million
# 9           Czech Republic            Prague     78,866 km²      10.7 million
# 10                 Denmark        Copenhagen     43,094 km²       5.8 million
# 11                 Estonia           Tallinn     45,226 km²       1.3 million
# 12                 Finland          Helsinki    338,455 km²       5.5 million
# 13                  France             Paris    547,030 km²      65.4 million
# 14                 Germany            Berlin    357,168 km²      83.9 million
# 15                  Greece            Athens    131,957 km²      10.3 million
# 16                 Hungary          Budapest     93,030 km²       9.6 million
# 17                 Iceland         Reykjavik    103,000 km²           343,353
# 18                 Ireland            Dublin     70,280 km²       4.9 million
# 19                   Italy              Rome    301,338 km²      60.3 million
# 20                  Kosovo         Prishtina     10,887 km²       1.9 million
# 21                  Latvia              Riga     64,589 km²       1.8 million
# 22           Liechtenstein             Vaduz        160 km²             38.25
# 23               Lithuania           Vilnius     65,300 km²       2.6 million
# 24              Luxembourg        Luxembourg      2,586 km²           634.814
# 25                   Malta          Valletta        316 km²           442.784
# 26                 Moldova          Chisinau     33,846 km²         4 million
# 27                  Monaco            Monaco      2.020 km²            39.511
# 28              Montenegro         Podgorica     13,812 km²           628.053
# 29             Netherlands         Amsterdam     41,543 km²      17.1 million
# 30         North Macedonia            Skopje     25,713 km²         2 million
# 31                  Norway              Oslo    385,203 km²       5.4 million
# 32                  Poland            Warsaw    312,685 km²      37.7 million
# 33                Portugal            Lisbon     92,212 km²      10.1 million
# 34                 Romania         Bucharest    238,397 km²      19.1 million
# 35                  Russia            Moscow  3,969,100 km²     145.9 million
# 36              San Marino        San Marino       61.2 km²            34.017
# 37                  Serbia          Belgrade     88,361 km²       8.6 million
# 38                Slovakia        Bratislava     49,035 km²       5.4 million
# 39                Slovenia         Ljubljana     20,273 km²         2 million
# 40                   Spain            Madrid    505,990 km²      46.7 million
# 41                  Sweden         Stockholm    450,295 km²      10.1 million
# 42             Switzerland              Bern     41,285 km²       8.7 million
# 43                 Ukraine              Kyiv    603,628 km²      43.4 million
# 44          United Kingdom            London    244,820 km²      68.2 million
# 45            Vatican City      Vatican City       0.44 km²               800

# %%
gdpdf
# Out:
#                    Country       2024    2023[5]       2022    2021[6]  \
# 0                  Germany  4,683.233  4,429.840  4,256.540  4,230.172
# 1           United Kingdom  3,557.465  3,332.060  3,376.003  3,108.416
# 2                   France  3,156.325  3,049.020  2,936.702  2,940.428
# 3                    Italy  2,365.541  2,186.080  2,058.330  2,120.232
# 4                   Russia  2,158.786  1,862.470  2,133.092  1,778.530
# 5                    Spain  1,724.379  1,620.091  1,446.498  1,461.245
# 6                   Turkey  1,312.932  1,154.060    905.527    817.508
# 7              Netherlands  1,209.072  1,092.750  1,013.595  1,007.562
# 8              Switzerland    935.316    905.684    841.969    810.830
# 9                   Poland    908.561    842.172    699.559    655.332
# 10                 Belgium    657.821    624.248    609.887    581.848
# 11                  Sweden    605.506    599.052    621.241    622.365
# 12                 Ireland    559.246    594.095    516.146    516.253
# 13                 Austria    533.147    515.199    479.815    481.209
# 14                  Norway    501.051    554.105    541.938    445.507
# 15                 Denmark    401.531    405.626    399.100    396.666
# 16                 Romania    376.243    348.902    312.492    287.279
# 17          Czech Republic    343.023    330.483    296.238    276.914
# 18                 Finland    308.055    301.670    297.617    296.016
# 19                Portugal    300.711    267.721    251.915    251.709
# 20              Kazakhstan    288.280    245.695    225.784    197.112
# 21                  Greece    250.615    239.300    222.770    211.645
# 22                 Hungary    226.413    188.505    197.813    180.959
# 23                 Ukraine    183.255    148.712    198.316    181.038
# 24                Slovakia    141.144    127.533    118.434    116.748
# 25                Bulgaria    107.427    100.635     89.533     77.907
# 26              Luxembourg     90.414     86.971     86.898     83.771
# 27                 Croatia     88.646     78.881     69.459     63.399
# 28               Lithuania     82.064     78.346     69.782     62.635
# 29                  Serbia     81.471     73.961     65.037     60.669
# 7                  Croatia            Zagreb     56,542 km²      4 million
# 8                   Cyprus           Nicosia      9,251 km²    1.2 million
# 9           Czech Republic            Prague     78,866 km²   10.7 million
# 10                 Denmark        Copenhagen     43,094 km²    5.8 million
# 11                 Estonia           Tallinn     45,226 km²    1.3 million
# 12                 Finland          Helsinki    338,455 km²    5.5 million
# 13                  France             Paris    547,030 km²   65.4 million
# 14                 Germany            Berlin    357,168 km²   83.9 million
# 15                  Greece            Athens    131,957 km²   10.3 million
# 16                 Hungary          Budapest     93,030 km²    9.6 million
# 17                 Iceland         Reykjavik    103,000 km²        343,353
# 18                 Ireland            Dublin     70,280 km²    4.9 million
# 19                   Italy              Rome    301,338 km²   60.3 million
# 20                  Kosovo         Prishtina     10,887 km²    1.9 million
# 21                  Latvia              Riga     64,589 km²    1.8 million
# 22           Liechtenstein             Vaduz        160 km²          38.25
# 23               Lithuania           Vilnius     65,300 km²    2.6 million
# 24              Luxembourg        Luxembourg      2,586 km²        634.814
# 25                   Malta          Valletta        316 km²        442.784
# 26                 Moldova          Chisinau     33,846 km²      4 million
# 27                  Monaco            Monaco      2.020 km²         39.511
# 28              Montenegro         Podgorica     13,812 km²        628.053
# 29             Netherlands         Amsterdam     41,543 km²   17.1 million
# 30         North Macedonia            Skopje     25,713 km²      2 million
# 31                  Norway              Oslo    385,203 km²    5.4 million
# 32                  Poland            Warsaw    312,685 km²   37.7 million
# 33                Portugal            Lisbon     92,212 km²   10.1 million
# 34                 Romania         Bucharest    238,397 km²   19.1 million
# 35                  Russia            Moscow  3,969,100 km²  145.9 million
# 36              San Marino        San Marino       61.2 km²         34.017
# 37                  Serbia          Belgrade     88,361 km²    8.6 million
# 38                Slovakia        Bratislava     49,035 km²    5.4 million
# 39                Slovenia         Ljubljana     20,273 km²      2 million
# 40                   Spain            Madrid    505,990 km²   46.7 million
# 41                  Sweden         Stockholm    450,295 km²   10.1 million
# 42             Switzerland              Bern     41,285 km²    8.7 million
# 43                 Ukraine              Kyiv    603,628 km²   43.4 million
# 44          United Kingdom            London    244,820 km²   68.2 million
# 45            Vatican City      Vatican City       0.44 km²            800

# %%
for i in range(len(popdf['Population'])):
    if 'million' in popdf['Population'][i]:
       popdf['Population'][i]=float(popdf['Population'][i].replace('million',''))*10**6

    else:
       popdf['Population'][i]=popdf['Population'][i].replace(".","")
       popdf['Population'][i]=popdf['Population'][i].replace(",", "")
popdf
# Out:
# <ipython-input-74-530f84d63f13>:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   popdf['Population'][i]=float(popdf['Population'][i].replace('million',''))*10**6
# <ipython-input-74-530f84d63f13>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   popdf['Population'][i]=popdf['Population'][i].replace(".","")
# <ipython-input-74-530f84d63f13>:7: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   popdf['Population'][i]=popdf['Population'][i].replace(",", "")
#                    Country           Capital           Area   Population
# 0                  Albania            Tirana     28,748 km²    2800000.0
# 1                  Andorra  Andorra la Vella        468 km²        77335
# 2                  Austria            Vienna     83,858 km²    9000000.0
# 3                  Belarus             Minsk    207,560 km²    9400000.0
# 4                  Belgium          Brussels     30,528 km²   11600000.0
# 5   Bosnia and Herzegovina          Sarajevo     51,129 km²    3200000.0
# 6                 Bulgaria             Sofia    110,910 km²    6800000.0
# 7                  Croatia            Zagreb     56,542 km²    4000000.0
# 8                   Cyprus           Nicosia      9,251 km²    1200000.0
# 9           Czech Republic            Prague     78,866 km²   10700000.0
# 10                 Denmark        Copenhagen     43,094 km²    5800000.0
# 11                 Estonia           Tallinn     45,226 km²    1300000.0
# 12                 Finland          Helsinki    338,455 km²    5500000.0
# 13                  France             Paris    547,030 km²   65400000.0
# 14                 Germany            Berlin    357,168 km²   83900000.0
# 15                  Greece            Athens    131,957 km²   10300000.0
# 16                 Hungary          Budapest     93,030 km²    9600000.0
# 17                 Iceland         Reykjavik    103,000 km²       343353
# 18                 Ireland            Dublin     70,280 km²    4900000.0
# 19                   Italy              Rome    301,338 km²   60300000.0
# 20                  Kosovo         Prishtina     10,887 km²    1900000.0
# 21                  Latvia              Riga     64,589 km²    1800000.0
# 22           Liechtenstein             Vaduz        160 km²         3825
# 23               Lithuania           Vilnius     65,300 km²    2600000.0
# 24              Luxembourg        Luxembourg      2,586 km²       634814
# 25                   Malta          Valletta        316 km²       442784
# 26                 Moldova          Chisinau     33,846 km²    4000000.0
# 27                  Monaco            Monaco      2.020 km²        39511
# 28              Montenegro         Podgorica     13,812 km²       628053
# 29             Netherlands         Amsterdam     41,543 km²   17100000.0
# 30         North Macedonia            Skopje     25,713 km²    2000000.0
# 31                  Norway              Oslo    385,203 km²    5400000.0
# 32                  Poland            Warsaw    312,685 km²   37700000.0
# 33                Portugal            Lisbon     92,212 km²   10100000.0
# 34                 Romania         Bucharest    238,397 km²   19100000.0
# 35                  Russia            Moscow  3,969,100 km²  145900000.0
# 36              San Marino        San Marino       61.2 km²        34017
# 37                  Serbia          Belgrade     88,361 km²    8600000.0
# 38                Slovakia        Bratislava     49,035 km²    5400000.0
# 39                Slovenia         Ljubljana     20,273 km²    2000000.0
# 40                   Spain            Madrid    505,990 km²   46700000.0
# 41                  Sweden         Stockholm    450,295 km²   10100000.0
# 42             Switzerland              Bern     41,285 km²    8700000.0
# 43                 Ukraine              Kyiv    603,628 km²   43400000.0
# 44          United Kingdom            London    244,820 km²   68200000.0
# 45            Vatican City      Vatican City       0.44 km²          800

# %%
popdf['Population']=popdf['Population'].astype(float).round(2)

# %%
for i in range(len(popdf['Area'])):
    if 'km²' in popdf['Area'][i]:
       popdf['Area'][i]=popdf['Area'][i].replace(',','')
       popdf['Area'][i]=float(popdf['Area'][i].replace('km²',''))

popdf
# Out:
# <ipython-input-76-72e7e50c81d0>:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   popdf['Area'][i]=popdf['Area'][i].replace(',','')
# <ipython-input-76-72e7e50c81d0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popdf['Area'][i]=popdf['Area'][i].replace(',','')
# <ipython-input-76-72e7e50c81d0>:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   popdf['Area'][i]=float(popdf['Area'][i].replace('km²',''))
# <ipython-input-76-72e7e50c81d0>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popdf['Area'][i]=float(popdf['Area'][i].replace('km²',''))
# <ipython-input-76-72e7e50c81d0>:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   popdf['Area'][i]=popdf['Area'][i].replace(',','')
# <ipython-input-76-72e7e50c81d0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popdf['Area'][i]=popdf['Area'][i].replace(',','')
# <ipython-input-76-72e7e50c81d0>:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   popdf['Area'][i]=float(popdf['Area'][i].replace('km²',''))
# <ipython-input-76-72e7e50c81d0>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popdf['Area'][i]=float(popdf['Area'][i].replace('km²',''))
# <ipython-input-76-72e7e50c81d0>:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   popdf['Area'][i]=popdf['Area'][i].replace(',','')
# <ipython-input-76-72e7e50c81d0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popdf['Area'][i]=popdf['Area'][i].replace(',','')
# <ipython-input-76-72e7e50c81d0>:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   popdf['Area'][i]=float(popdf['Area'][i].replace('km²',''))
# <ipython-input-76-72e7e50c81d0>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popdf['Area'][i]=float(popdf['Area'][i].replace('km²',''))
# <ipython-input-76-72e7e50c81d0>:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   popdf['Area'][i]=popdf['Area'][i].replace(',','')
# <ipython-input-76-72e7e50c81d0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popdf['Area'][i]=popdf['Area'][i].replace(',','')
# <ipython-input-76-72e7e50c81d0>:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   popdf['Area'][i]=float(popdf['Area'][i].replace('km²',''))
# <ipython-input-76-72e7e50c81d0>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popdf['Area'][i]=float(popdf['Area'][i].replace('km²',''))
# <ipython-input-76-72e7e50c81d0>:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   popdf['Area'][i]=popdf['Area'][i].replace(',','')
# <ipython-input-76-72e7e50c81d0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popdf['Area'][i]=popdf['Area'][i].replace(',','')
# <ipython-input-76-72e7e50c81d0>:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   popdf['Area'][i]=float(popdf['Area'][i].replace('km²',''))
# <ipython-input-76-72e7e50c81d0>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popdf['Area'][i]=float(popdf['Area'][i].replace('km²',''))
# <ipython-input-76-72e7e50c81d0>:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   popdf['Area'][i]=popdf['Area'][i].replace(',','')
# <ipython-input-76-72e7e50c81d0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popdf['Area'][i]=popdf['Area'][i].replace(',','')
# <ipython-input-76-72e7e50c81d0>:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   popdf['Area'][i]=float(popdf['Area'][i].replace('km²',''))
# <ipython-input-76-72e7e50c81d0>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popdf['Area'][i]=float(popdf['Area'][i].replace('km²',''))
# <ipython-input-76-72e7e50c81d0>:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   popdf['Area'][i]=popdf['Area'][i].replace(',','')
# <ipython-input-76-72e7e50c81d0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popdf['Area'][i]=popdf['Area'][i].replace(',','')
# <ipython-input-76-72e7e50c81d0>:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   popdf['Area'][i]=float(popdf['Area'][i].replace('km²',''))
# <ipython-input-76-72e7e50c81d0>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popdf['Area'][i]=float(popdf['Area'][i].replace('km²',''))
# <ipython-input-76-72e7e50c81d0>:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   popdf['Area'][i]=popdf['Area'][i].replace(',','')
# <ipython-input-76-72e7e50c81d0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popdf['Area'][i]=popdf['Area'][i].replace(',','')
# <ipython-input-76-72e7e50c81d0>:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   popdf['Area'][i]=float(popdf['Area'][i].replace('km²',''))
# <ipython-input-76-72e7e50c81d0>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popdf['Area'][i]=float(popdf['Area'][i].replace('km²',''))
# <ipython-input-76-72e7e50c81d0>:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   popdf['Area'][i]=popdf['Area'][i].replace(',','')
# <ipython-input-76-72e7e50c81d0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popdf['Area'][i]=popdf['Area'][i].replace(',','')
# <ipython-input-76-72e7e50c81d0>:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   popdf['Area'][i]=float(popdf['Area'][i].replace('km²',''))
# <ipython-input-76-72e7e50c81d0>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popdf['Area'][i]=float(popdf['Area'][i].replace('km²',''))
# <ipython-input-76-72e7e50c81d0>:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   popdf['Area'][i]=popdf['Area'][i].replace(',','')
# <ipython-input-76-72e7e50c81d0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popdf['Area'][i]=popdf['Area'][i].replace(',','')
# <ipython-input-76-72e7e50c81d0>:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   popdf['Area'][i]=float(popdf['Area'][i].replace('km²',''))
# <ipython-input-76-72e7e50c81d0>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popdf['Area'][i]=float(popdf['Area'][i].replace('km²',''))
# <ipython-input-76-72e7e50c81d0>:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   popdf['Area'][i]=popdf['Area'][i].replace(',','')
# <ipython-input-76-72e7e50c81d0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popdf['Area'][i]=popdf['Area'][i].replace(',','')
# <ipython-input-76-72e7e50c81d0>:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   popdf['Area'][i]=float(popdf['Area'][i].replace('km²',''))
# <ipython-input-76-72e7e50c81d0>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popdf['Area'][i]=float(popdf['Area'][i].replace('km²',''))
# <ipython-input-76-72e7e50c81d0>:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   popdf['Area'][i]=popdf['Area'][i].replace(',','')
# <ipython-input-76-72e7e50c81d0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popdf['Area'][i]=popdf['Area'][i].replace(',','')
# <ipython-input-76-72e7e50c81d0>:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   popdf['Area'][i]=float(popdf['Area'][i].replace('km²',''))
# <ipython-input-76-72e7e50c81d0>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popdf['Area'][i]=float(popdf['Area'][i].replace('km²',''))
# <ipython-input-76-72e7e50c81d0>:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   popdf['Area'][i]=popdf['Area'][i].replace(',','')
# <ipython-input-76-72e7e50c81d0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popdf['Area'][i]=popdf['Area'][i].replace(',','')
# <ipython-input-76-72e7e50c81d0>:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   popdf['Area'][i]=float(popdf['Area'][i].replace('km²',''))
# <ipython-input-76-72e7e50c81d0>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popdf['Area'][i]=float(popdf['Area'][i].replace('km²',''))
# <ipython-input-76-72e7e50c81d0>:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   popdf['Area'][i]=popdf['Area'][i].replace(',','')
# <ipython-input-76-72e7e50c81d0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popdf['Area'][i]=popdf['Area'][i].replace(',','')
# <ipython-input-76-72e7e50c81d0>:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   popdf['Area'][i]=float(popdf['Area'][i].replace('km²',''))
# <ipython-input-76-72e7e50c81d0>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popdf['Area'][i]=float(popdf['Area'][i].replace('km²',''))
# <ipython-input-76-72e7e50c81d0>:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   popdf['Area'][i]=popdf['Area'][i].replace(',','')
# <ipython-input-76-72e7e50c81d0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popdf['Area'][i]=popdf['Area'][i].replace(',','')
# <ipython-input-76-72e7e50c81d0>:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   popdf['Area'][i]=float(popdf['Area'][i].replace('km²',''))
# <ipython-input-76-72e7e50c81d0>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popdf['Area'][i]=float(popdf['Area'][i].replace('km²',''))
# <ipython-input-76-72e7e50c81d0>:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   popdf['Area'][i]=popdf['Area'][i].replace(',','')
# <ipython-input-76-72e7e50c81d0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popdf['Area'][i]=popdf['Area'][i].replace(',','')
# <ipython-input-76-72e7e50c81d0>:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   popdf['Area'][i]=float(popdf['Area'][i].replace('km²',''))
# <ipython-input-76-72e7e50c81d0>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popdf['Area'][i]=float(popdf['Area'][i].replace('km²',''))
# <ipython-input-76-72e7e50c81d0>:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   popdf['Area'][i]=popdf['Area'][i].replace(',','')
# <ipython-input-76-72e7e50c81d0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popdf['Area'][i]=popdf['Area'][i].replace(',','')
# <ipython-input-76-72e7e50c81d0>:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   popdf['Area'][i]=float(popdf['Area'][i].replace('km²',''))
# <ipython-input-76-72e7e50c81d0>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popdf['Area'][i]=float(popdf['Area'][i].replace('km²',''))
# <ipython-input-76-72e7e50c81d0>:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   popdf['Area'][i]=popdf['Area'][i].replace(',','')
# <ipython-input-76-72e7e50c81d0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popdf['Area'][i]=popdf['Area'][i].replace(',','')
# <ipython-input-76-72e7e50c81d0>:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   popdf['Area'][i]=float(popdf['Area'][i].replace('km²',''))
# <ipython-input-76-72e7e50c81d0>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popdf['Area'][i]=float(popdf['Area'][i].replace('km²',''))
# <ipython-input-76-72e7e50c81d0>:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   popdf['Area'][i]=popdf['Area'][i].replace(',','')
# <ipython-input-76-72e7e50c81d0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popdf['Area'][i]=popdf['Area'][i].replace(',','')
# <ipython-input-76-72e7e50c81d0>:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   popdf['Area'][i]=float(popdf['Area'][i].replace('km²',''))
# <ipython-input-76-72e7e50c81d0>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popdf['Area'][i]=float(popdf['Area'][i].replace('km²',''))
# <ipython-input-76-72e7e50c81d0>:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   popdf['Area'][i]=popdf['Area'][i].replace(',','')
# <ipython-input-76-72e7e50c81d0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popdf['Area'][i]=popdf['Area'][i].replace(',','')
# <ipython-input-76-72e7e50c81d0>:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   popdf['Area'][i]=float(popdf['Area'][i].replace('km²',''))
# <ipython-input-76-72e7e50c81d0>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popdf['Area'][i]=float(popdf['Area'][i].replace('km²',''))
# <ipython-input-76-72e7e50c81d0>:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   popdf['Area'][i]=popdf['Area'][i].replace(',','')
# <ipython-input-76-72e7e50c81d0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popdf['Area'][i]=popdf['Area'][i].replace(',','')
# <ipython-input-76-72e7e50c81d0>:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   popdf['Area'][i]=float(popdf['Area'][i].replace('km²',''))
# <ipython-input-76-72e7e50c81d0>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popdf['Area'][i]=float(popdf['Area'][i].replace('km²',''))
# <ipython-input-76-72e7e50c81d0>:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   popdf['Area'][i]=popdf['Area'][i].replace(',','')
# <ipython-input-76-72e7e50c81d0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popdf['Area'][i]=popdf['Area'][i].replace(',','')
# <ipython-input-76-72e7e50c81d0>:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   popdf['Area'][i]=float(popdf['Area'][i].replace('km²',''))
# <ipython-input-76-72e7e50c81d0>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popdf['Area'][i]=float(popdf['Area'][i].replace('km²',''))
# <ipython-input-76-72e7e50c81d0>:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   popdf['Area'][i]=popdf['Area'][i].replace(',','')
# <ipython-input-76-72e7e50c81d0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popdf['Area'][i]=popdf['Area'][i].replace(',','')
# <ipython-input-76-72e7e50c81d0>:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   popdf['Area'][i]=float(popdf['Area'][i].replace('km²',''))
# <ipython-input-76-72e7e50c81d0>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popdf['Area'][i]=float(popdf['Area'][i].replace('km²',''))
# <ipython-input-76-72e7e50c81d0>:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   popdf['Area'][i]=popdf['Area'][i].replace(',','')
# <ipython-input-76-72e7e50c81d0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popdf['Area'][i]=popdf['Area'][i].replace(',','')
# <ipython-input-76-72e7e50c81d0>:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   popdf['Area'][i]=float(popdf['Area'][i].replace('km²',''))
# <ipython-input-76-72e7e50c81d0>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popdf['Area'][i]=float(popdf['Area'][i].replace('km²',''))
# <ipython-input-76-72e7e50c81d0>:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   popdf['Area'][i]=popdf['Area'][i].replace(',','')
# <ipython-input-76-72e7e50c81d0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popdf['Area'][i]=popdf['Area'][i].replace(',','')
# <ipython-input-76-72e7e50c81d0>:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   popdf['Area'][i]=float(popdf['Area'][i].replace('km²',''))
# <ipython-input-76-72e7e50c81d0>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popdf['Area'][i]=float(popdf['Area'][i].replace('km²',''))
#                    Country           Capital       Area   Population
# 0                  Albania            Tirana    28748.0    2800000.0
# 1                  Andorra  Andorra la Vella      468.0      77335.0
# 2                  Austria            Vienna    83858.0    9000000.0
# 3                  Belarus             Minsk   207560.0    9400000.0
# 4                  Belgium          Brussels    30528.0   11600000.0
# 5   Bosnia and Herzegovina          Sarajevo    51129.0    3200000.0
# 6                 Bulgaria             Sofia   110910.0    6800000.0
# 7                  Croatia            Zagreb    56542.0    4000000.0
# 8                   Cyprus           Nicosia     9251.0    1200000.0
# 9           Czech Republic            Prague    78866.0   10700000.0
# 10                 Denmark        Copenhagen    43094.0    5800000.0
# 11                 Estonia           Tallinn    45226.0    1300000.0
# 12                 Finland          Helsinki   338455.0    5500000.0
# 13                  France             Paris   547030.0   65400000.0
# 14                 Germany            Berlin   357168.0   83900000.0
# 15                  Greece            Athens   131957.0   10300000.0
# 16                 Hungary          Budapest    93030.0    9600000.0
# 17                 Iceland         Reykjavik   103000.0     343353.0
# 18                 Ireland            Dublin    70280.0    4900000.0
# 19                   Italy              Rome   301338.0   60300000.0
# 20                  Kosovo         Prishtina    10887.0    1900000.0
# 21                  Latvia              Riga    64589.0    1800000.0
# 22           Liechtenstein             Vaduz      160.0       3825.0
# 23               Lithuania           Vilnius    65300.0    2600000.0
# 24              Luxembourg        Luxembourg     2586.0     634814.0
# 25                   Malta          Valletta      316.0     442784.0
# 26                 Moldova          Chisinau    33846.0    4000000.0
# 27                  Monaco            Monaco       2.02      39511.0
# 28              Montenegro         Podgorica    13812.0     628053.0
# 29             Netherlands         Amsterdam    41543.0   17100000.0
# 30         North Macedonia            Skopje    25713.0    2000000.0
# 31                  Norway              Oslo   385203.0    5400000.0
# 32                  Poland            Warsaw   312685.0   37700000.0
# 33                Portugal            Lisbon    92212.0   10100000.0
# 34                 Romania         Bucharest   238397.0   19100000.0
# 35                  Russia            Moscow  3969100.0  145900000.0
# 36              San Marino        San Marino       61.2      34017.0
# 37                  Serbia          Belgrade    88361.0    8600000.0
# 38                Slovakia        Bratislava    49035.0    5400000.0
# 39                Slovenia         Ljubljana    20273.0    2000000.0
# 40                   Spain            Madrid   505990.0   46700000.0
# 41                  Sweden         Stockholm   450295.0   10100000.0
# 42             Switzerland              Bern    41285.0    8700000.0
# 43                 Ukraine              Kyiv   603628.0   43400000.0
# 44          United Kingdom            London   244820.0   68200000.0
# 45            Vatican City      Vatican City       0.44        800.0

# %%
popdf['Population Density']=popdf['Population']/popdf['Area']
popdf
# Out:
#                    Country           Capital       Area   Population  \
# 0                  Albania            Tirana    28748.0    2800000.0
# 1                  Andorra  Andorra la Vella      468.0      77335.0
# 2                  Austria            Vienna    83858.0    9000000.0
# 3                  Belarus             Minsk   207560.0    9400000.0
# 4                  Belgium          Brussels    30528.0   11600000.0
# 5   Bosnia and Herzegovina          Sarajevo    51129.0    3200000.0
# 6                 Bulgaria             Sofia   110910.0    6800000.0
# 7                  Croatia            Zagreb    56542.0    4000000.0
# 8                   Cyprus           Nicosia     9251.0    1200000.0
# 9           Czech Republic            Prague    78866.0   10700000.0
# 10                 Denmark        Copenhagen    43094.0    5800000.0
# 11                 Estonia           Tallinn    45226.0    1300000.0
# 12                 Finland          Helsinki   338455.0    5500000.0
# 13                  France             Paris   547030.0   65400000.0
# 14                 Germany            Berlin   357168.0   83900000.0
# 15                  Greece            Athens   131957.0   10300000.0
# 16                 Hungary          Budapest    93030.0    9600000.0
# 17                 Iceland         Reykjavik   103000.0     343353.0
# 18                 Ireland            Dublin    70280.0    4900000.0
# 19                   Italy              Rome   301338.0   60300000.0
# 20                  Kosovo         Prishtina    10887.0    1900000.0
# 21                  Latvia              Riga    64589.0    1800000.0
# 22           Liechtenstein             Vaduz      160.0       3825.0
# 23               Lithuania           Vilnius    65300.0    2600000.0
# 24              Luxembourg        Luxembourg     2586.0     634814.0
# 25                   Malta          Valletta      316.0     442784.0
# 26                 Moldova          Chisinau    33846.0    4000000.0
# 27                  Monaco            Monaco       2.02      39511.0
# 28              Montenegro         Podgorica    13812.0     628053.0
# 29             Netherlands         Amsterdam    41543.0   17100000.0
# 30         North Macedonia            Skopje    25713.0    2000000.0
# 31                  Norway              Oslo   385203.0    5400000.0
# 32                  Poland            Warsaw   312685.0   37700000.0
# 33                Portugal            Lisbon    92212.0   10100000.0
# 34                 Romania         Bucharest   238397.0   19100000.0
# 35                  Russia            Moscow  3969100.0  145900000.0
# 36              San Marino        San Marino       61.2      34017.0
# 37                  Serbia          Belgrade    88361.0    8600000.0
# 38                Slovakia        Bratislava    49035.0    5400000.0
# 39                Slovenia         Ljubljana    20273.0    2000000.0
# 40                   Spain            Madrid   505990.0   46700000.0
# 41                  Sweden         Stockholm   450295.0   10100000.0
# 42             Switzerland              Bern    41285.0    8700000.0
# 43                 Ukraine              Kyiv   603628.0   43400000.0
# 44          United Kingdom            London   244820.0   68200000.0
# 45            Vatican City      Vatican City       0.44        800.0
#
#    Population Density
# 0            97.39808
# 1          165.245726
# 2          107.324286
# 3           45.288109
# 4          379.979036
# 5            62.58679
# 6           61.310973
# 7           70.743872
# 8          129.715706
# 9          135.673167
# 10         134.589502
# 11          28.744527
# 12          16.250314
# 13         119.554686
# 14         234.903463
# 15           78.05573
# 16         103.192519
# 17           3.333524
# 18          69.721116
# 19          200.10752
# 20          174.52007
# 21          27.868523
# 22           23.90625
# 23          39.816233
# 24         245.481052
# 25         1401.21519
# 26         118.182355
# 27        19559.90099
# 28          45.471546
# 29         411.621693
# 30          77.781667
# 31          14.018582
# 32         120.568623
# 33         109.530213
# 34          80.118458
# 35          36.758963
# 36         555.833333
# 37          97.328007
# 38         110.125421
# 39          98.653381
# 40          92.294314
# 41          22.429741
# 42         210.730289
# 43          71.898587
# 44         278.572012
# 45        1818.181818

# %%
finaldata =pd.merge(popdf,gdpdf,on='Country')
finaldata
# Out:
#                    Country     Capital       Area   Population  \
# 0                  Albania      Tirana    28748.0    2800000.0
# 1                  Austria      Vienna    83858.0    9000000.0
# 2                  Belarus       Minsk   207560.0    9400000.0
# 3                  Belgium    Brussels    30528.0   11600000.0
# 4   Bosnia and Herzegovina    Sarajevo    51129.0    3200000.0
# 5                 Bulgaria       Sofia   110910.0    6800000.0
# 6                  Croatia      Zagreb    56542.0    4000000.0
# 7                   Cyprus     Nicosia     9251.0    1200000.0
# 8           Czech Republic      Prague    78866.0   10700000.0
# 9                  Denmark  Copenhagen    43094.0    5800000.0
# 10                 Estonia     Tallinn    45226.0    1300000.0
# 11                 Finland    Helsinki   338455.0    5500000.0
# 12                  France       Paris   547030.0   65400000.0
# 13                 Germany      Berlin   357168.0   83900000.0
# 39   15.418   15.059   13.059   11.868   11.364   13.219   12.804   12.323
# 48    3.155    3.238    3.021    2.879    2.813    3.355    3.283    3.164
# 40   13.444   12.433   11.527   10.546   10.553   11.610   11.121   10.619
# 13  447.718  456.166  417.721  394.215  381.998  442.698  430.203  409.652
# 30   47.171   46.940   41.375   37.830   50.844   75.240   74.160   69.687
# 31   62.572   59.643   54.723   47.703   56.329   78.736   75.496   65.669
# 10  517.609  532.268  495.953  469.931  456.067  531.651  521.090  498.161
# 38   20.106   20.162   18.081   16.910   16.210   18.522   18.155   17.207
# 25   66.250   65.197   58.342   53.236   50.201   56.815   55.557   53.901
# 27   60.702   60.805   55.201   51.623   49.519   57.683   58.158   56.549
#
#        2011     2010
# 39   12.896   11.938
# 48    3.447    3.359
# 40   10.142    9.260
# 13  431.515  392.623
# 30   65.990   52.913
# 31   61.368   57.220
# 10  527.492  484.450
# 38   18.629   17.164
# 25   57.420   50.611
# 27   62.399   59.866

# %%
finaldata['2024']=finaldata['2024'].str.replace(",","").astype(float).round(2)

# %%
finaldata['GDP per capita']=finaldata['2024']*10**9/finaldata['2024']
finaldata
# Out:
#                    Country     Capital       Area   Population  \
# 0                  Albania      Tirana    28748.0    2800000.0
# 1                  Austria      Vienna    83858.0    9000000.0
# 2                  Belarus       Minsk   207560.0    9400000.0
# 3                  Belgium    Brussels    30528.0   11600000.0
# 4   Bosnia and Herzegovina    Sarajevo    51129.0    3200000.0
# 5                 Bulgaria       Sofia   110910.0    6800000.0
# 6                  Croatia      Zagreb    56542.0    4000000.0
# 7                   Cyprus     Nicosia     9251.0    1200000.0
# 8           Czech Republic      Prague    78866.0   10700000.0
# 9                  Denmark  Copenhagen    43094.0    5800000.0
# 10                 Estonia     Tallinn    45226.0    1300000.0
# 11                 Finland    Helsinki   338455.0    5500000.0
# 12                  France       Paris   547030.0   65400000.0
# 13                 Germany      Berlin   357168.0   83900000.0
# 14                  Greece      Athens   131957.0   10300000.0
# 15                 Hungary    Budapest    93030.0    9600000.0
# 16                 Iceland   Reykjavik   103000.0     343353.0
# 17                 Ireland      Dublin    70280.0    4900000.0
# 18                   Italy        Rome   301338.0   60300000.0
# 19                  Kosovo   Prishtina    10887.0    1900000.0
# 20                  Latvia        Riga    64589.0    1800000.0
# 21               Lithuania     Vilnius    65300.0    2600000.0
# 22              Luxembourg  Luxembourg     2586.0     634814.0
# 23                   Malta    Valletta      316.0     442784.0
# 24                 Moldova    Chisinau    33846.0    4000000.0
# 25              Montenegro   Podgorica    13812.0     628053.0
# 26             Netherlands   Amsterdam    41543.0   17100000.0
# 27         North Macedonia      Skopje    25713.0    2000000.0
# 28                  Norway        Oslo   385203.0    5400000.0
# 29                  Poland      Warsaw   312685.0   37700000.0
# 30                Portugal      Lisbon    92212.0   10100000.0
# 31                 Romania   Bucharest   238397.0   19100000.0
# 32                  Russia      Moscow  3969100.0  145900000.0
# 33              San Marino  San Marino       61.2      34017.0
# 34                  Serbia    Belgrade    88361.0    8600000.0
# 35                Slovakia  Bratislava    49035.0    5400000.0
# 2   ...     59.643     54.723     47.703     56.329     78.736     75.496
# 3   ...    532.268    495.953    469.931    456.067    531.651    521.090
# 4   ...     20.162     18.081     16.910     16.210     18.522     18.155
# 5   ...     65.197     58.342     53.236     50.201     56.815     55.557
# 6   ...     60.805     55.201     51.623     49.519     57.683     58.158
# 7   ...     24.493     22.189     20.461     19.691     23.401     24.094
# 8   ...    245.226    215.914    195.090    186.830    207.818    209.402
# 9   ...    352.058    329.866    311.988    302.673    352.994    343.584
# 10  ...     30.761     26.850     23.994     22.916     26.658     25.145
# 11  ...    274.210    252.867    239.150    232.582    273.042    270.065
# 12  ...  2,780.152  2,591.775  2,466.152  2,439.435  2,856.697  2,811.957
# 13  ...  3,951.340  3,664.511  3,496.606  3,383.091  3,904.921  3,753.687
# 14  ...    218.230    203.493    195.303    196.690    237.406    239.937
# 15  ...    161.182    139.844    126.008    123.074    140.083    135.221
# 16  ...     25.965     24.457     20.618     17.389     17.758     16.034
# 17  ...    382.754    335.211    301.968    290.858    259.200    238.708
# 18  ...  2,075.856  1,950.703  1,869.973  1,833.195  2,155.151  2,131.159
# 19  ...      7.947      7.243      6.717      6.444      7.398      7.075
# 20  ...     34.882     30.528     27.707     26.986     31.385     30.260
# 21  ...     53.302     47.645     42.991     41.538     48.632     46.423
# 22  ...     69.553     62.449     58.985     57.233     66.209     61.759
# 23  ...     14.560     12.764     11.446     10.701     11.302     10.154
# 24  ...     11.309      9.670      8.072      7.726      9.510      9.496
# 25  ...      5.457      4.855      4.376      4.055      4.595      4.466
# 26  ...    914.519    833.575    783.852    765.650    892.397    877.198
# 27  ...     12.670     11.308     10.686     10.067     11.378     10.824
# 28  ...    434.167    398.394    371.345    386.663    499.338    523.502
# 29  ...    585.816    526.749    471.843    477.568    545.284    524.399
# 30  ...    240.901    221.280    206.361    199.521    229.995    226.144
# 31  ...    239.552    211.407    188.495    177.895    199.628    190.948
# 32  ...  1,657.290  1,579.293  1,282.663  1,363.707  2,056.583  2,289.244
# 33  ...      1.638      1.528      1.468      1.420      1.674      1.678
# 34  ...     50.509     44.120     40.630     39.629     47.062     48.394
# 35  ...    106.573     95.821     89.885     87.814    101.109     98.509
# 36  ...     54.059     48.545     44.660     43.124     49.969     48.131
# 37  ...  1,431.643  1,321.754  1,243.016  1,206.165  1,380.245  1,362.187
# 38  ...    556.073    540.545    512.205    498.118    574.413    579.361
# 39  ...    705.546    680.029    670.247    679.721    709.496    688.747
# 40  ...    130.857    112.125     93.313     90.489    130.571    179.572
# 41  ...  2,828.833  2,640.067  2,669.107  2,897.060  3,036.310  2,755.356
#
#          2012       2011       2010 GDP per capita
# 0      12.323     12.896     11.938   1.000000e+09
# 1     409.652    431.515    392.623   1.000000e+09
# 2      65.669     61.368     57.220   1.000000e+09
# 3     498.161    527.492    484.450   1.000000e+09
# 4      17.207     18.629     17.164   1.000000e+09
# 5      53.901     57.420     50.611   1.000000e+09
# 6      56.549     62.399     59.866   1.000000e+09
# 7      25.055     27.454     25.608   1.000000e+09
# 8     207.376    227.948    207.478   1.000000e+09
# 9     327.149    344.003    321.995   1.000000e+09
# 10     23.057     23.191     19.536   1.000000e+09
# 11    256.849    273.925    248.262   1.000000e+09
# 12  2,685.311  2,864.030  2,647.537   1.000000e+09
# 13  3,545.946  3,761.142   3,423.47   1.000000e+09
# 14    245.807    288.062    299.919   1.000000e+09
# 15    127.857    140.782    130.923   1.000000e+09
# 16     14.724     15.159     13.684   1.000000e+09
# 17    225.140    238.088    222.533   1.000000e+09
# 18  2,073.971  2,278.376  2,129.021   1.000000e+09
# 19      6.503      6.699      5.841   1.000000e+09
# 20     28.141     28.496     23.809   1.000000e+09
# 21     42.887     43.564     37.200   1.000000e+09
# 22     56.709     60.060     53.312   1.000000e+09
# 23      9.215      9.511      8.757   1.000000e+09
# 24      8.708      8.417      6.977   1.000000e+09
# 25      4.090      4.543      4.147   1.000000e+09
# 26    839.436    904.915    848.133   1.000000e+09
# 27      9.751     10.659      9.415   1.000000e+09
# 28    510.229    498.832    429.131   1.000000e+09
# 29    500.846    528.571    479.161   1.000000e+09
# 30    216.488    245.119    238.748   1.000000e+09
# 31    171.196    183.443    166.225   1.000000e+09
# 32  2,202.672  2,044.618  1,632.841   1.000000e+09
# 33      1.606      1.813      1.883   1.000000e+09
# 34     43.300     49.280     41.369   1.000000e+09
# 35     93.466     98.271     89.668   1.000000e+09
# 36     46.378     51.338     48.103   1.000000e+09
# 37  1,330.995  1,487.569  1,427.989   1.000000e+09
# 38    544.482    563.797    488.909   1.000000e+09
# 39    667.890    699.670    583.053   1.000000e+09
# 40    175.707    163.161    136.011   1.000000e+09
# 41  2,677.082  2,635.799  2,455.309   1.000000e+09
#
# [42 rows x 21 columns]

# %%
dff = finaldata[['Population','Population Density','GDP per capita','2024']]

dff = dff.sort_values(by='GDP per capita').round(2)

dff['Country']=finaldata['Country'].values
dff
# Out:
#      Population Population Density  GDP per capita     2024  \
# 3    11600000.0         379.979036    1.000000e+09   657.82
# 5     6800000.0          61.310973    1.000000e+09   107.43
# 6     4000000.0          70.743872    1.000000e+09    88.65
# 37   46700000.0          92.294314    1.000000e+09  1724.38
# 4     3200000.0           62.58679    1.000000e+09    28.21
# 1     9000000.0         107.324286    1.000000e+09   533.15
# 7     1200000.0         129.715706    1.000000e+09    34.22
# 0     2800000.0           97.39808    1.000000e+09    26.13
# 15    9600000.0         103.192519    1.000000e+09   226.41
# 10    1300000.0          28.744527    1.000000e+09    42.78
# 11    5500000.0          16.250314    1.000000e+09   308.06
# 12   65400000.0         119.554686    1.000000e+09  3156.32
# 14   10300000.0           78.05573    1.000000e+09   250.62
# 18   60300000.0          200.10752    1.000000e+09  2365.54
# 17    4900000.0          69.721116    1.000000e+09   559.25
# 8    10700000.0         135.673167    1.000000e+09   343.02
# 24    4000000.0         118.182355    1.000000e+09    18.36
# 25     628053.0          45.471546    1.000000e+09     8.01
# 26   17100000.0         411.621693    1.000000e+09  1209.07
# 19    1900000.0          174.52007    1.000000e+09    11.32
# 20    1800000.0          27.868523    1.000000e+09    45.24
# 21    2600000.0          39.816233    1.000000e+09    82.06
# 22     634814.0         245.481052    1.000000e+09    90.41
# 23     442784.0         1401.21519    1.000000e+09    24.10
# 28    5400000.0          14.018582    1.000000e+09   501.05
# 31   19100000.0          80.118458    1.000000e+09   376.24
# 27    2000000.0          77.781667    1.000000e+09    15.87
# 38   10100000.0          22.429741    1.000000e+09   605.51
# 33      34017.0         555.833333    1.000000e+09     2.04
# 34    8600000.0          97.328007    1.000000e+09    81.47
# 32  145900000.0          36.758963    1.000000e+09  2158.79
# 16     343353.0           3.333524    1.000000e+09    33.34
# 41   68200000.0         278.572012    1.000000e+09  3557.46
# 36    2000000.0          98.653381    1.000000e+09    72.61
# 39    8700000.0         210.730289    1.000000e+09   935.32
# 40   43400000.0          71.898587    1.000000e+09   183.26
# 2     9400000.0          45.288109    1.000000e+09    72.99
# 29   37700000.0         120.568623    1.000000e+09   908.56
# 9     5800000.0         134.589502    1.000000e+09   401.53
# 13   83900000.0         234.903463    1.000000e+09  4683.23
# 30   10100000.0         109.530213    1.000000e+09   300.71
# 35    5400000.0         110.125421    1.000000e+09   141.14
#
#                    Country
# 3                  Albania
# 5                  Austria
# 6                  Belarus
# 37                 Belgium
# 4   Bosnia and Herzegovina
# 1                 Bulgaria
# 7                  Croatia
# 0                   Cyprus
# 15          Czech Republic
# 10                 Denmark
# 11                 Estonia
# 12                 Finland
# 14                  France
# 18                 Germany
# 17                  Greece
# 8                  Hungary
# 24                 Iceland
# 25                 Ireland
# 26                   Italy
# 19                  Kosovo
# 20                  Latvia
# 21               Lithuania
# 22              Luxembourg
# 23                   Malta
# 28                 Moldova
# 31              Montenegro
# 27             Netherlands
# 38         North Macedonia
# 33                  Norway
# 34                  Poland
# 32                Portugal
# 16                 Romania
# 41                  Russia
# 36              San Marino
# 39                  Serbia
# 40                Slovakia
# 2                 Slovenia
# 29                   Spain
# 9                   Sweden
# 13             Switzerland
# 30                 Ukraine
# 35          United Kingdom

# %%
#Make scatter plot
x = finaldata['Population Density']
y = finaldata['GDP per capita']

# %%
#Makeheatmap
import seaborn as sns
dff = finaldata[['Country','Population','Population Density','GDP per capita','2024']][:]
dff = dff.set_index('Country')
plt.figure(figsize=(10,15))
sns.heatmap(dff.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.show()

# %%
finaldata.sort_values(by='2024', ascending=False,inplace= True)

# %%
dff = finaldata[['Population','Population Density','GDP per capita','2024']]

dff = dff.copy().round(2)

dff['Country']=finaldata['Country'].values

# %%
#makeheatmap
import seaborn as sns
import pandas as pd

dff = finaldata[['Country','Population','Population Density','GDP per capita','2024']][:]
dff= dff.set_index('Country')

for col in dff.columns:
    dfn[col] = pd.to_numeric(dff[col], errors='coerce')
    dff.fillna(0, inplace=True)

plt.figure(figsize=(10,15))
sns.heatmap(dff.astype(float))
plt.show()

# %%
#Store in csv
finaldata.to_csv("europedata.csv")

# %%
#makeheatmap
import seaborn as sns
import pandas as pd

dff = finaldata[['Country','Population','Population Density','GDP per capita','2024']][:]
dff= dff.set_index('Country')

# Convert all columns to numeric, replacing errors with NaN
for col in dff.columns:
    dff[col] = pd.to_numeric(dff[col], errors='coerce')

# Fill NaN values with 0
dff.fillna(0, inplace=True)

plt.figure(figsize=(10,15))
sns.heatmap(dff) # No need to convert to float here as we already did
plt.show()

# %%
# Apply filtering conditions on the scaled dataframe
filtered_dfn = dfn[
    (dfn['Population Density'] > 1.3) &
    (dfn['Population'] > 1.5) &
    (dfn['2024'] > 1.3) &
    (dfn['GDP per capita'] > 1.5)
]

# Plot heatmap for the filtered countries
plt.figure(figsize=(10, 6))  # Adjust size if needed
sns.heatmap(filtered_dfn) # Replaced _______ with filtered_dfn

# Show the heatmap
plt.title("Heatmap of Selected Countries")
plt.show()

# %% [markdown]
# # New Section

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'finaldata' contains your dataset, replace 'data' with 'finaldata'
data = pd.read_csv("europedata.csv")  # Assuming you saved your data in "europedata.csv"

# Rename columns for clarity (If needed, adjust column names to match your dataset)
# data = data.rename(columns={"ColumnName": "NewColumnName"})  # Example rename

# Select relevant columns for analysis
df_selected = data[["Country", "Population", "Population Density", "GDP per capita", "2024"]]  # Assuming "2024" represents "GDP (Billion)"

# Define weights for scoring
weights = {
    "GDP per capita": 0.4,     # Higher purchasing power
    "Population": 0.3,         # Large customer base
    "Population Density": 0.2, # Urbanization & foot traffic
    "2024": 0.1              # Economic stability (Assuming "2024" is your GDP column)
}

# Normalize data using Min-Max Scaling
df_normalized = df_selected.copy()
for col in weights.keys():
    df_normalized[col] = (df_normalized[col] - df_normalized[col].min()) / (df_normalized[col].max() - df_normalized[col].min())

# Compute the Retail Score using weighted sum
df_normalized["Retail Score"] = sum(df_normalized[col] * weight for col, weight in weights.items())

# Get top 10 countries for retail expansion
top_10_countries = df_normalized.nlargest(10, "Retail Score")[["Country", "Retail Score"]]

# Filter the dataset to include only these top 10 countries
df_top_10 = df_normalized[df_normalized["Country"].isin(top_10_countries["Country"])]

# Set Country as index for visualization
df_top_10 = df_top_10.set_index("Country")

# Heatmap for only the top 10 countries
plt.figure(figsize=(12, 8))
sns.heatmap(df_top_10)  # Pass the filtered DataFrame here
plt.title("Retail Expansion Potential - Top 10 Countries")
plt.show()

# %%
#Load dataset
# Assuming 'data' is the DataFrame from "europedata.csv"
# If a different DataFrame should be used, replace 'data' accordingly.

# Rename columns for clarity (If needed)
# data = data.rename(columns={"OldColumnName": "NewColumnName", ...})  # Example rename


# Select relevant columns for analysis
df_selected = data[["Country", "Population", "Population Density", "GDP per capita", "2024"]]  # Assuming "2024" represents "GDP (Billion)"

# Define weights for scoring
weights = {
    "GDP per capita": 0.4,     # Higher purchasing power
    "Population": 0.2,         # Large customer base
    "Population Density": 0.2, # Urbanization & foot traffic
    "2024": 0.2       # Economic stability
}

# Normalize data using Min-Max Scaling (but scaled between 1 and 5 instead of 0 and 1)
df_scaled = df_selected.copy()
for col in weights.keys():
    df_scaled[col] = 1 + 4 * (df_scaled[col] - df_scaled[col].min()) / (df_scaled[col].max() - df_scaled[col].min())

# Compute the Retail Score using weighted sum
df_scaled["Retail Score"] = sum(df_scaled[col] * weight for col, weight in weights.items())

# Get top 10 countries for retail expansion
top_10_countries = df_scaled.nlargest(10, "Retail Score")[["Country", "Retail Score"]]

# Filter the dataset to include only these top 10 countries
df_top_10 = df_scaled[df_scaled["Country"].isin(top_10_countries["Country"])]

# Set Country as index for visualization
df_top_10 = df_top_10.set_index("Country")

# Heatmap for only the top 10 countries (with values between 1 and 5)
plt.figure(figsize=(12, 8))
sns.heatmap(df_top_10) # Pass the correctly filtered and scaled DataFrame
plt.title("Retail Expansion Potential - Top 10 Countries (Scaled 1 to 5)")
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset, assigning to data3
data3 = pd.read_csv("europedata.csv")  # Assuming europedata.csv contains the relevant data

# Rename columns for clarity (If needed)
# data3 = data3.rename(columns={"OldColumnName": "NewColumnName", ...})  # Example rename

# Select relevant columns for analysis
# The column name was likely incorrect, changed from "GDP (Billion)" to "2024"
df_selected = data3[["Country", "Population", "Population Density", "GDP per capita", "2024"]]

# Define updated weights
weights = {
    "GDP per capita": 0.3,     # Purchasing power
    "Population": 0.15,        # Market size
    "Population Density": 0.15,# Urbanization & foot traffic
    "2024": 0.4       # Economic stability & growth
}

# Normalize data using Min-Max Scaling (Scaled between 1 and 5)
df_scaled = df_selected.copy()
for col in weights.keys():
    df_scaled[col] = 1 + 4 * (df_scaled[col] - df_scaled[col].min()) / (df_scaled[col].max() - df_scaled[col].min())

# Compute the new Retail Score using weighted sum
df_scaled["Retail Score"] = sum(df_scaled[col] * weight for col, weight in weights.items())

# Get top 10 countries for retail expansion based on new weights
top_10_countries = df_scaled.nlargest(10, "Retail Score")[["Country", "Retail Score"]]

# Filter the dataset to include only the top 10 countries
df_top_10 = df_scaled[df_scaled["Country"].isin(top_10_countries["Country"])].set_index("Country")

# Heatmap for the top 10 countries (values scaled between 1 and 5)
plt.figure(figsize=(12, 8))
sns.heatmap(df_top_10) # Pass df_top_10 to sns.heatmap

# Title and show plot
plt.title("Retail Expansion Potential - Top 10 Countries (Scaled 1 to 5)")
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Assign the filename to file_path
file_path = "europedata.csv"
df = pd.read_csv(file_path)

# Select relevant columns for analysis
df_selected = df[["Country", "Population", "Population Density", "GDP per capita", "2024"]] # Assuming "2024" represents "GDP (Billion)"

# Define updated weights
weights = {
    "GDP per capita": 0.3,     # Purchasing power
    "Population": 0.15,        # Market size
    "Population Density": 0.15,# Urbanization & foot traffic
    "2024": 0.4       # Economic stability & growth
}

# Normalize data using Min-Max Scaling (Scaled between 1 and 5)
df_scaled = df_selected.copy()
for col in weights.keys():
    df_scaled[col] = 1 + 4 * (df_scaled[col] - df_scaled[col].min()) / (df_scaled[col].max() - df_scaled[col].min())

# Compute the new Retail Score using weighted sum
df_scaled["Retail Score"] = sum(df_scaled[col] * weight for col, weight in weights.items())

# Get top 10 countries for retail expansion based on new weights
top_10_countries = df_scaled.nlargest(10, "Retail Score")

# Sort by Retail Score before plotting
df_top_10 = top_10_countries.set_index("Country").sort_values(by="Retail Score", ascending=False)

# Heatmap for the top 10 countries (values scaled between 1 and 5)
plt.figure(figsize=(12, 8))
sns.heatmap(df_top_10) # Pass the DataFrame containing data for the top 10 countries

# Title and show plot
plt.title("Retail Expansion Potential - Top 10 Countries (Sorted by Retail Score)")
plt.show()
